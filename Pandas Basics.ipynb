# %%
import pandas as pd

# %%
df_csv=pd.read_csv("D:\Mechaine_Learning_Journey\Quality of life data.csv")
print(df_csv.head())
df_pokemon = pd.read_json(r"D:\Mechaine_Learning_Journey\pokemon.json")
print(df_pokemon.head())
# Out:
#       id  gender occupation_type  avg_work_hours_per_day  \
# 0  10001  Female         Teacher                    6.60
# 1  10002    Male   Office Worker                    9.65
# 2  10003  Female         Manager                   13.77
# 3  10004  Female      Freelancer                   10.94
# 4  10005    Male        Engineer                    9.81
#
#    avg_rest_hours_per_day  avg_sleep_hours_per_day  \
# 0                   10.92                     5.38
# 1                    7.65                     6.31
# 2                    1.00                     8.02
# 3                    5.18                     7.59
# 4                    5.11                     7.38
#
#    avg_exercise_hours_per_day  age_at_death
# 0                        1.10            88
# 1                        0.39            76
# 2                        1.21            78
# 3                        0.29            74
# 4                        1.70            78
#                     name             type  total  hp  attack
# 0              Bulbasaur  [Grass, Poison]    318  45      49
# 1                Ivysaur  [Grass, Poison]    405  60      62
# 2               Venusaur  [Grass, Poison]    525  80      82
# 3  VenusaurMega Venusaur  [Grass, Poison]    625  80     100
# 4             Charmander           [Fire]    309  39      52
