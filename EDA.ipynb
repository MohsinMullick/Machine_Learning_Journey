# %%
import pandas as pd

# %%
df=pd.read_json("D:\Mechaine_Learning_Journey\pokemon.json")

# %%
print("Print the json file\n",df)
# Out:
# Print the json file
#                        name              type  total  hp  attack
# 0                Bulbasaur   [Grass, Poison]    318  45      49
# 1                  Ivysaur   [Grass, Poison]    405  60      62
# 2                 Venusaur   [Grass, Poison]    525  80      82
# 3    VenusaurMega Venusaur   [Grass, Poison]    625  80     100
# 4               Charmander            [Fire]    309  39      52
# ..                     ...               ...    ...  ..     ...
# 795                Diancie     [Rock, Fairy]    600  50     100
# 796    DiancieMega Diancie     [Rock, Fairy]    700  50     160
# 797    HoopaHoopa Confined  [Psychic, Ghost]    600  80     110
# 798     HoopaHoopa Unbound   [Psychic, Dark]    680  80     160
# 799              Volcanion     [Fire, Water]    600  80     110
#
# [800 rows x 5 columns]

# %%
print("First 5 row default\n",df.head())
# Out:
# First 5 row default
#                      name             type  total  hp  attack
# 0              Bulbasaur  [Grass, Poison]    318  45      49
# 1                Ivysaur  [Grass, Poison]    405  60      62
# 2               Venusaur  [Grass, Poison]    525  80      82
# 3  VenusaurMega Venusaur  [Grass, Poison]    625  80     100
# 4             Charmander           [Fire]    309  39      52

# %%
print(df.shape)#row and column size
# Out:
# (800, 5)

# %%
print(df.info)#show the some information
# Out:
# <bound method DataFrame.info of                       name              type  total  hp  attack
# 0                Bulbasaur   [Grass, Poison]    318  45      49
# 1                  Ivysaur   [Grass, Poison]    405  60      62
# 2                 Venusaur   [Grass, Poison]    525  80      82
# 3    VenusaurMega Venusaur   [Grass, Poison]    625  80     100
# 4               Charmander            [Fire]    309  39      52
# ..                     ...               ...    ...  ..     ...
# 795                Diancie     [Rock, Fairy]    600  50     100
# 796    DiancieMega Diancie     [Rock, Fairy]    700  50     160
# 797    HoopaHoopa Confined  [Psychic, Ghost]    600  80     110
# 798     HoopaHoopa Unbound   [Psychic, Dark]    680  80     160
# 799              Volcanion     [Fire, Water]    600  80     110
#
# [800 rows x 5 columns]>

# %%
print(df.isnull().sum())#just check the missing value
# Out:
# name      0
# type      0
# total     0
# hp        0
# attack    0
# dtype: int64

# %%
df['type']=df['type'].apply(tuple)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#                       name              type  total  hp  attack  \
# 0                Bulbasaur   (Grass, Poison)    318  45      49
# 1                  Ivysaur   (Grass, Poison)    405  60      62
# 2                 Venusaur   (Grass, Poison)    525  80      82
# 3    VenusaurMega Venusaur   (Grass, Poison)    625  80     100
# 4               Charmander           (Fire,)    309  39      52
# ..                     ...               ...    ...  ..     ...
# 795                Diancie     (Rock, Fairy)    600  50     100
# 796    DiancieMega Diancie     (Rock, Fairy)    700  50     160
# 797    HoopaHoopa Confined  (Psychic, Ghost)    600  80     110
# 798     HoopaHoopa Unbound   (Psychic, Dark)    680  80     160
# 799              Volcanion     (Fire, Water)    600  80     110
#
#                 tkype
# 0     (Grass, Poison)
# 1     (Grass, Poison)
# 2     (Grass, Poison)
# 3     (Grass, Poison)
# 4             (Fire,)
# ..                ...
# 795     (Rock, Fairy)
# ...

# %%
df.describe()
# Out:
#            total          hp      attack
# count  800.00000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250
# std    119.96304   25.534669   32.457366
# min    180.00000    1.000000    5.000000
# 25%    330.00000   50.000000   55.000000
# 50%    450.00000   65.000000   75.000000
# 75%    515.00000   80.000000  100.000000
# max    780.00000  255.000000  190.000000
